# %% [markdown]
# # Scraping Meralco Website's August update for Electric Price

# %%
meralcoWeb = requests.get("https://company.meralco.com.ph/news-and-advisories/august-2024-rates-updates#:~:text=The%20Manila%20Electric%20Company%20(Meralco,6012%20per%20kWh.").content

scrapeMeralco = bs(meralcoWeb, 'html.parser')

scrapeMeralco
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
# <head>
# <script src="https://company.meralco.com.ph/static/9fb0ca009155840e3ed4fa627a8239b129740017c7657a" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-110657135-1"></script>
# <script>window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}gtag('js',new Date());gtag('config','UA-110657135-1');</script>
# <meta charset="utf-8"/>
# <meta content="Meralco" property="og:site_name"/>
# <meta content="index, follow" name="robots"/>
# <meta content="Article" property="og:type"/>
# <meta content="Meralco celebrates 120 years of service in 2023. Our mission is to provide our customers the best value in energy, products and services." name="description"/>
# <meta content="https://company.meralco.com.ph/news-and-advisories/august-2024-rates-updates" property="og:url"/>
# ...

# %%
firstParagraph = scrapeMeralco.find(attrs = {"class":"node-field body"})

type(firstParagraph)
# Out:
# bs4.element.Tag

# %%
print(firstParagraph.p.string)
# Out:
# The Manila Electric Company (Meralco) announced today a minimal upward adjustment of P0.0327 per kWh in the electricity rate for August, resulting in an overall rate of P11.6339 per kWh for a typical household, up from the previous month’s P11.6012 per kWh.
